# %% [markdown]
# # Welcome to the NMCC Coding Class

# %% [markdown]
# ### Outline for the day

# %% [markdown]
# 1. Brief Introduction
# 2. Tour of the Website
# 3. Jupyter notebook Setup
#
#     a. Windows:  https://docs.anaconda.com/anaconda/install/windows/
#
#     b. Mac:   https://docs.anaconda.com/anaconda/install/mac-os/
# 4. Google colab: You will need a gmail account

# %% [markdown]
# ### Procedure

# %% [markdown]
# A procedure is a set of steps you take to accomplish a task. For example, you want to make a toast bread, you might follow the folloiwng steps:
# 1. Get the bread and butter from the refrigerator
# 2. Open the bread bag and take out some slices of the  bread
# 3. Remove the cover of the toaster
# 4. Place two of the slices in the slot
# 5. Push the toaster lever down to start toasting the bread
# 6. Wait for the toasting process to complete
# 7. Remove the toasted bread from the toaster
# 8. Place toast on a plate
# 9. Butter the bread.
# #### Think of something you do daily and the steps you take to accomplish the task

# %% [markdown]
# ### Applications

# %% [markdown]
# 1. An application, also referred to as an application program or application software, is a computer software package that performs a specific function directly for an end user or, in some cases, for another application.
# 2. An application can be self-contained or a group of programs. The program is a set of operations that runs the application for the user.
# 3. When you write an application, you’re writing a procedure that defines a series of steps that the computer should perform to accomplish whatever task you have in mind. If you leave out a step, the results won’t be what you expected.
# 4. The computer won’t know what you mean or that you intended for it to perform certain tasks automatically. The only thing the computer knows is that you have provided it with a specific procedure and it needs to perform that procedure. `GARBAGE IN GARBAGE OUT`

# %% [markdown]
# #### Programming Languages

# %% [markdown]
# 1. For any application, we need to write programs for what task to be performed.
# 2. There are thousands of programming languages which includes Python, Java, JAvascript, PHP, C, C++, C# etc

# %%
from IPython.display import Image
Image(filename='programs.png')  #source:  https://www.siliconrepublic.com/careers/python-most-in-demand-coding-language-2022

# %% [markdown]
# #### Python  Editors

# %% [markdown]
# An editor is a program or platform where you create your code, run and test it. Most editors have debugging features that allows you to trace your code/program in the event that it is giving required result or its not running at all. Examples of Python editors include
# 1. `Python IDLE`
# 2. `Visual Studio Code`
# 3. `Jupiter Notebook`
# 4. `Spyder` and so on
#
# We will be using `Jupyter notebook` which is what we installed earlier and what I am using right now.

# %% [markdown]
# ### Algorithms and Pseudocode

# %% [markdown]
# An algorithm is a procedure for solving a problem in terms of the actions to be executed and the order in which those actions are to be executed. An algorithm is merely the sequence of steps taken to solve a problem.
#
# Pseudocode is an artificial and informal language that helps programmers develop algorithms. Pseudocode is a "text-based" detail (algorithmic) design tool. For example, if I want to compute the average grade of subjects taken by a student, a pseudocode will look like this
# 1. `Initialize total grade to  zero`
# 2. `Initialize count to zero`
# 2. `For each subject
#     Input the grade
#     Add the grade to total score
#     Increase count by one`
# 3. `If count is greater than zero
#      Divide total grade by count`

# %% [markdown]
# ### Our First program

# %%
print('Hello World')
# Out:
# Hello World
